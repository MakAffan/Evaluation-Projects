# %% [markdown]
# # Importing Libraries & Data

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')

# %% [markdown]
# # Understanding the Data

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# # Understanding Features

# %%
sns.countplot(x='W', data = df, palette = "twilight_shifted")
# Out:
# <Axes: xlabel='W', ylabel='count'>

# %%
plt.figure(figsize = (10, 6), facecolor = "white")
plotnumber = 1
for c in df.columns:
    if plotnumber <= 17:
        x=plt.subplot(4,5,plotnumber)
        sns.histplot(df[c], palette = "twilight_shifted")
        plt.xlabel(c, fontsize = 10)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Outlier Check

# %%
plt.figure(figsize = (10, 20), facecolor = "white")
plotnumber = 1
for c in df.columns:
    if plotnumber <= 17:
        x=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[c], palette = "Set2_r")
        plt.xlabel(c, fontsize = 10)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %%
sns.pairplot(df, hue='W', palette="colorblind")
plt.show()

# %%
plt.figure(figsize = (10, 20), facecolor = "white")
plotnumber = 1
for c in df.columns:
    if plotnumber <= 17:
        x=plt.subplot(6,3,plotnumber)
        sns.regplot(x='W', y=df[c], data = df)
        plt.xlabel('W', fontsize = 10)
        plt.ylabel(c, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Correlation Check

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,fmt='0.2f',cmap='Spectral')
plt.show()

# %%
corr['W'].sort_values(ascending = False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# # Skewness Check

# %%
plt.figure(figsize = (10, 6), facecolor = "white")
plotnumber = 1
for c in df.columns:
    if plotnumber <= 17:
        x=plt.subplot(4,5,plotnumber)
        sns.distplot(df[c],color = "b")
        plt.xlabel(c, fontsize = 10)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %%
skew = df.skew()
skew
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
for i,score in skew.iteritems():
    if score > 0.5 or score < -0.5:
        df[i] = np.cbrt(df[i])
df.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.642599
# 2B    -0.230650
# 3B     0.129502
# HR     0.175310
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -1.043632
# SHO   -0.280283
# SV     0.325143
# E      0.719735
# dtype: float64

# %% [markdown]
# Assign feature and target data

# %%
x = df.drop('W', axis =1)
y = df['W']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.650959  0.847731  1.654199  1.420173  1.041193 -0.775226 -1.534902
# 1   0.164710 -0.711094 -0.978027  0.127403  1.235809 -0.186932 -0.536592
# 2  -0.316685 -1.115233 -0.140129  1.588795 -0.223808 -0.703608  1.139144
# 3  -1.186544  0.241522 -0.393166 -0.828122 -0.418423 -0.883952 -1.160536
# 4   0.041117  1.280738  1.962309  0.801892  1.722347 -0.355325 -0.251360
# 5   3.317778 -0.104884  1.360930  1.869832 -1.391501  2.018459  1.798742
# 6   1.324315  0.732263 -0.104119 -0.153633 -1.196885  1.491597  1.513510
# 7   0.461454 -0.451289 -0.593183 -1.615025 -1.099578  1.626318 -0.910958
# 8  -0.774111 -0.451289 -0.356913  0.183611  0.068115  0.171256 -0.590073
# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0    10.539359        R
# 1     4.190335       AB
# 2     8.365365        H
# 3     4.064841       2B
# 4     2.990873       3B
# 5     9.633282       HR
# 6     3.732781       BB
# 7     2.756326       SO
# 8     1.741301       SB
# 9   170.239204       RA
# 10  171.315583       ER
# 11    2.630729       CG
# 12    2.911872      SHO
# 13    2.787382       SV
# 14    2.073039        E

# %% [markdown]
# # Model Creation

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

# %%
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
        
print(maxAccu," at ",maxRS)
# Out:
# 0.882713450380623  at  129

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = maxRS)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
plr = lr.predict(x_test)
ptrain = lr.predict(x_train)
print(lr)
print('r2_score :',r2_score(y_test,plr))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_squared_error :',mean_squared_error(y_test,plr))
print('mean_absolute_error :',mean_absolute_error(y_test,plr))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,plr)))
# Out:
# LinearRegression()
# r2_score : 0.882713450380623
# r2_score on train data : 92.52087016639395
# mean_squared_error : 14.772313323665239
# mean_absolute_error : 3.1190640640222815
# root mean squared error : 3.8434767234452245

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
prfr = rfr.predict(x_test)
ptrain = rfr.predict(x_train)
print(rfr)
print('r2_score :',r2_score(y_test,prfr))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_absolute_error :',mean_absolute_error(y_test,prfr))
print('mean_squared_error :',mean_squared_error(y_test,prfr))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,prfr)))
# Out:
# RandomForestRegressor()
# r2_score : 0.6261953832581846
# r2_score on train data : 94.02431891588262
# mean_absolute_error : 5.190000000000001
# mean_squared_error : 47.08092222222224
# root mean squared error : 6.86155392183303

# %%
knn = KNN()
knn.fit(x_train,y_train)
pknn = knn.predict(x_test)
ptrain = knn.predict(x_train)
print(knn)
print('r2_score :',r2_score(y_test,pknn))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_absolute_error :',mean_absolute_error(y_test,pknn))
print('mean_squared_error :',mean_squared_error(y_test,pknn))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pknn)))
# Out:
# KNeighborsRegressor()
# r2_score : 0.6095824348167027
# r2_score on train data : 54.30782193512146
# mean_absolute_error : 6.266666666666666
# mean_squared_error : 49.17333333333332
# root mean squared error : 7.012370022562509

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pgbr = gbr.predict(x_test)
ptrain = gbr.predict(x_train)
print(gbr)
print('r2_score :',r2_score(y_test,pgbr))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_absolute_error :',mean_absolute_error(y_test,pgbr))
print('mean_squared_error :',mean_squared_error(y_test,pgbr))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pgbr)))
# Out:
# GradientBoostingRegressor()
# r2_score : 0.40515536582058864
# r2_score on train data : 99.99999904297323
# mean_absolute_error : 7.734672373171443
# mean_squared_error : 74.92104886294265
# root mean squared error : 8.655694591593598

# %%
lasso = Lasso()
lasso.fit(x_train,y_train)
plasso = lasso.predict(x_test)
ptrain = lasso.predict(x_train)
print(lasso)
print('r2_score :',r2_score(y_test,plasso))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_absolute_error :',mean_absolute_error(y_test,plasso))
print('mean_squared_error :',mean_squared_error(y_test,plasso))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,plasso)))
# Out:
# Lasso()
# r2_score : 0.9290034346451503
# r2_score on train data : 85.75092470040873
# mean_absolute_error : 2.4754539117150376
# mean_squared_error : 8.942061231483654
# root mean squared error : 2.990327947146208

# %%
ridge = Ridge()
ridge.fit(x_train,y_train)
pridge = ridge.predict(x_test)
ptrain = ridge.predict(x_train)
print(ridge)
print('r2_score :',r2_score(y_test,pridge))
print('r2_score on train data :',r2_score(y_train,ptrain)*100)
print('mean_absolute_error :',mean_absolute_error(y_test,pridge))
print('mean_squared_error :',mean_squared_error(y_test,pridge))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pridge)))
# Out:
# Ridge()
# r2_score : 0.9177833454704164
# r2_score on train data : 90.47594302675309
# mean_absolute_error : 2.4617452334248924
# mean_squared_error : 10.355238389022366
# root mean squared error : 3.217955622599909

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,plr)-score.mean())*100)
# Out:
# [ 0.55564034 -4.90589933  0.4078918   0.5839298   0.29773622]
# -0.6121402338430335
# Diff b/w R2 and cross val score is : 149.48536842236564

# %%
score = cross_val_score(rfr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,prfr)-score.mean())*100)
# Out:
# [ 0.26476448 -4.79279733  0.22659886  0.36633369  0.75439976]
# -0.6361401084326623
# Diff b/w R2 and cross val score is : 126.2335491690847

# %%
score = cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,pknn)-score.mean())*100)
# Out:
# [ 0.10756661 -2.33801527  0.15977152  0.3384741   0.55088757]
# -0.23626309456134004
# Diff b/w R2 and cross val score is : 84.58455293780428

# %%
score = cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,pgbr)-score.mean())*100)
# Out:
# [-0.29901061 -6.46959276  0.2322884   0.254016    0.56684616]
# -1.1430905610223552
# Diff b/w R2 and cross val score is : 154.82459268429437

# %%
score = cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,plasso)-score.mean())*100)
# Out:
# [ 0.76099326 -0.29816038  0.65638898  0.68043282  0.91958096]
# 0.5438471261195831
# Diff b/w R2 and cross val score is : 38.515630852556725

# %%
score = cross_val_score(ridge,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Diff b/w R2 and cross val score is :",(r2_score(y_test,pridge)-score.mean())*100)
# Out:
# [ 0.6158945  -0.90274234  0.50876127  0.71152212  0.8519253 ]
# 0.3570721705173593
# Diff b/w R2 and cross val score is : 56.071117495305714

# %% [markdown]
# Lasso is used as the final model as it has the best performance

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'alpha' : [0.0001, 0.001, 0.01, 0.1, 1, 10],
              'fit_intercept' : [True, False],
              'copy_X' : [True, False],
              'tol' : [0.0001, 0.001, 0.01, 0.1, 1, 10]}

# %%
gscv = GridSearchCV(Lasso(),parameters,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'tol': 0.0001}

# %% [markdown]
# # Final Model

# %%
Model = Lasso(alpha = 1, copy_X = True, fit_intercept = True, tol = 0.0001)
Model.fit(x_train,y_train)
pred = Model.predict(x_test)
print('r2_score :',r2_score(y_test,pred))
print('mean_absolute_error :',mean_absolute_error(y_test,pred))
print('mean_squared_error :',mean_squared_error(y_test,pred))
print('root mean squared error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score : 0.9290034346451503
# mean_absolute_error : 2.4754539117150376
# mean_squared_error : 8.942061231483654
# root mean squared error : 2.990327947146208

# %%
import pickle
filename = 'Baseball.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
load_model = pickle.load(open('Baseball.pkl','rb'))
result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 92.90034346451503
